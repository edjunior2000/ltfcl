# %% [markdown]
# <a href="https://colab.research.google.com/github/edjunior2000/ltfcl/blob/main/ltfcl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://github.com/edjunior2000/ltfcl/raw/main/ltfcl_data/ltfcl_data.csv'
dados = pd.read_csv(url)
testea= dados.head(1000)
testeb= dados.loc[1000:1999,:]
dados
# Out:
#       concurso  dia  mês   ano  dez1  ...  dez11  dez12  dez13  dez14  dez15
# 0            1   29    9  2003     2  ...     18     20     23     24     25
# 1            2    6   10  2003     1  ...     16     19     20     23     24
# 2            3   13   10  2003     1  ...     16     17     20     23     24
# 3            4   20   10  2003     1  ...     18     19     23     24     25
# 4            5   27   10  2003     1  ...     19     20     23     24     25
# ...        ...  ...  ...   ...   ...  ...    ...    ...    ...    ...    ...
# 2221      2221    4    5  2021     1  ...     16     18     20     22     23
# 2222      2222    5    5  2021     2  ...     14     19     22     23     24
# 2223      2223    6    5  2021     1  ...     20     21     22     24     25
# 2224      2224    7    5  2021     3  ...     18     19     20     23     24
# 2225      2225    8    5  2021     2  ...     19     21     22     23     25
#
# [2226 rows x 19 columns]

# %%
u = testea['dez1']==1
v= testea[u]
# Out:
#      concurso  dia  mês   ano  dez1  ...  dez11  dez12  dez13  dez14  dez15
# 1           2    6   10  2003     1  ...     16     19     20     23     24
# 2           3   13   10  2003     1  ...     16     17     20     23     24
# 3           4   20   10  2003     1  ...     18     19     23     24     25
# 4           5   27   10  2003     1  ...     19     20     23     24     25
# 5           6    3   11  2003     1  ...     17     19     21     23     25
# ..        ...  ...  ...   ...   ...  ...    ...    ...    ...    ...    ...
# 990       991    6   12  2013     1  ...     18     21     22     24     25
# 991       992    9   12  2013     1  ...     15     17     19     20     24
# 994       995   16   12  2013     1  ...     17     20     22     23     24
# 997       998   23   12  2013     1  ...     19     20     21     22     23
# 998       999   27   12  2013     1  ...     15     16     18     21     24
#
# [620 rows x 19 columns]

# %%
dados['dez6'].value_counts()
# Out:
# 9     435
# 10    423
# 11    358
# 8     315
# 12    254
# 7     205
# 13    128
# 6      61
# 14     35
# 15     11
# 16      1
# Name: dez6, dtype: int64

# %%
testea['dez13'].hist(bins=20)

# %%
testeb['dez13'].hist(bins=20)

# %%
testea.describe()
# Out:
#           concurso          dia  ...        dez14        dez15
# count  1000.000000  1000.000000  ...  1000.000000  1000.000000
# mean    500.500000    15.773000  ...    22.841000    24.373000
# std     288.819436     8.781149  ...     1.216223     0.955397
# min       1.000000     1.000000  ...    18.000000    20.000000
# 25%     250.750000     8.000000  ...    22.000000    24.000000
# 50%     500.500000    16.000000  ...    23.000000    25.000000
# 75%     750.250000    23.000000  ...    24.000000    25.000000
# max    1000.000000    31.000000  ...    24.000000    25.000000
#
# [8 rows x 19 columns]

# %%
testea.loc[:,'dez1':'dez15'].describe()
# Out:
#               dez1         dez2  ...        dez14        dez15
# count  1000.000000  1000.000000  ...  1000.000000  1000.000000
# mean      1.561000     3.193000  ...    22.841000    24.373000
# std       0.864307     1.273331  ...     1.216223     0.955397
# min       1.000000     2.000000  ...    18.000000    20.000000
# 25%       1.000000     2.000000  ...    22.000000    24.000000
# 50%       1.000000     3.000000  ...    23.000000    25.000000
# 75%       2.000000     4.000000  ...    24.000000    25.000000
# max       6.000000     9.000000  ...    24.000000    25.000000
#
# [8 rows x 15 columns]

# %%
testea.loc[:,'dez1':'dez15'].describe().T
# Out:
#         count    mean       std   min   25%   50%   75%   max
# dez1   1000.0   1.561  0.864307   1.0   1.0   1.0   2.0   6.0
# dez2   1000.0   3.193  1.273331   2.0   2.0   3.0   4.0   9.0
# dez3   1000.0   4.808  1.511099   3.0   4.0   5.0   6.0  11.0
# dez4   1000.0   6.449  1.708894   4.0   5.0   6.0   8.0  12.0
# dez5   1000.0   8.120  1.842008   5.0   7.0   8.0   9.0  14.0
# dez6   1000.0   9.741  1.909336   6.0   8.0  10.0  11.0  15.0
# dez7   1000.0  11.350  1.911322   7.0  10.0  11.0  13.0  16.0
# dez8   1000.0  12.962  1.911599   8.0  12.0  13.0  14.0  17.0
# dez9   1000.0  14.567  1.973171   9.0  13.0  15.0  16.0  19.0
# dez10  1000.0  16.228  1.923465  10.0  15.0  16.0  18.0  20.0
# dez11  1000.0  17.877  1.810842  12.0  17.0  18.0  19.0  21.0
# dez12  1000.0  19.504  1.700846  13.0  18.0  20.0  21.0  22.0
# dez13  1000.0  21.183  1.483142  15.0  20.0  21.0  22.0  23.0
# dez14  1000.0  22.841  1.216223  18.0  22.0  23.0  24.0  24.0
# ...

# %%
testea.loc[:,'dez1':'dez15'].hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3348ca5850>,
# ...
#       dtype=object)

# %%
testeb.loc[:,'dez1':'dez15'].describe()
# Out:
#               dez1         dez2  ...        dez14        dez15
# count  1000.000000  1000.000000  ...  1000.000000  1000.000000
# mean      1.652000     3.294000  ...    22.772000    24.389000
# std       0.956981     1.330915  ...     1.296803     0.940512
# min       1.000000     2.000000  ...    17.000000    18.000000
# 25%       1.000000     2.000000  ...    22.000000    24.000000
# 50%       1.000000     3.000000  ...    23.000000    25.000000
# 75%       2.000000     4.000000  ...    24.000000    25.000000
# max       6.000000     9.000000  ...    24.000000    25.000000
#
# [8 rows x 15 columns]
